# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "date": ["5/12/2025", "6/12/2025"],
    "amount": [500, 600],
    "category": ["vadapav", "taxi"]
    })

print(df)
# Out:
#         date  amount category
# 0  5/12/2025     500  vadapav
# 1  6/12/2025     600     taxi

# %%
new_exp = pd.DataFrame({
    "date": ["12/12/2025"],
    "amount": [10000],
    "category": ["G Lab"] 
})

# %%
print(pd.concat([df, new_exp], ignore_index=True))
total_expense = pd.concat([df, new_exp], ignore_index=True)
# Out:
#          date  amount category
# 0   5/12/2025     500  vadapav
# 1   6/12/2025     600     taxi
# 2  12/12/2025   10000    G Lab

# %%
print(total_expense["amount"].sum())
# Out:
# 11100

# %%
# access sep col
print(total_expense["category"]);print(df.loc[1, "amount"])
# Out:
# 0    vadapav
# 1       taxi
# 2      G Lab
# Name: category, dtype: object
# 600

# %%
import pandas as pd 
product_catalog = pd.DataFrame({
    "product_id": [101, 102, 103, 104, 105],
    "product_name": ["Laptop", "Mouse", "Keyboard", "Monitor", "Headphones"],
    "price": [999.99, 25.50, 75.00, 299.99, 149.99],
    "stock": [15, 150, 89, 42, 67],
    "category": ["Electronics", "Accessories", "Accessories", "Electronics", "Accessories"]
})

print(product_catalog)
# Out:
#    product_id product_name   price  stock     category
# 0         101       Laptop  999.99     15  Electronics
# 1         102        Mouse   25.50    150  Accessories
# 2         103     Keyboard   75.00     89  Accessories
# 3         104      Monitor  299.99     42  Electronics
# 4         105   Headphones  149.99     67  Accessories

# %%
print(product_catalog["product_name"]);print(product_catalog.loc[1, "price"])
# Out:
# 0        Laptop
# 1         Mouse
# 2      Keyboard
# 3       Monitor
# 4    Headphones
# Name: product_name, dtype: object
# 25.5
