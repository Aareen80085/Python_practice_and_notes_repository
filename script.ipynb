# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1,2,3,4,5,6])
y = x ** 2

# uni_dis = np.random.normal(10, 20 , 5)
# norm_dis = np.random.uniform(1 ,7 , 5)
# plt.grid(True)
# plt.barh(x,y)
# plt.title("uniform vs normal distribution")
# plt.xlabel("random data x")
# plt.ylabel("random data y")
# plt.legend()
# plt.savefig("niggagraph.pdf")
# plt.show()

# plt.pie(x,y)
plt.pie(x)
colours=["red","green","blue","purple","brown","orange"]
labels =["age", "gender", "race", "ethnicity", "language","color"]

plt.pie(x, colors=colours)
plt.pie(x, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x10fda7110>,
# ...
#  [Text(1.0877139078161349, 0.1639464996373907, 'age'),
#   Text(0.9088626361528681, 0.6196520867432462, 'gender'),
#   Text(0.24477282280271442, 1.0724207500870129, 'race'),
#   Text(-0.8063573127136769, 0.7481897381234106, 'ethnicity'),
#   Text(-0.9088625450470076, -0.6196522203709725, 'language'),
#   Text(0.6858390281006222, -0.8600144344916508, 'color')])
