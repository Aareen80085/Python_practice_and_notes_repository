# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("./supermarket_sales.csv")
number_unitprice = df["Unit price"]

plt.hist(number_unitprice, edgecolor = "black", color="green")
plt.title("Price of each product in $")
plt.show()
# ages = np.random.normal(18,10,100)
# plt.hist(ages,bins=10, edgecolor="black",color="green")
# plt.xlabel("gay")
# plt.ylabel("niggas")
# plt.title("gay vs niggas")
# plt.show()
