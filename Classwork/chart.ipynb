# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
days= np.arange(1,8)
errors=[1,7,8,6,10,3,11]
days_in_words = ["mon","tue","wed","thur","fri","sat","sun"]

plt.xticks(days,days_in_words)

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.stem(days,errors)


plt.show()
