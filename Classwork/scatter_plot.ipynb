# %%
import matplotlib.pyplot as plt

# %%
scores_in_sub_A=[30,25,15,50,6]
scores_in_sub_B=[10,35,25,20,8]
hrs_studied=[20,15,10,48,8]

plt.scatter(scores_in_sub_A,hrs_studied, color="red", s=100,label ="python")
plt.scatter(scores_in_sub_B,hrs_studied,color="green", s=100,label="C++")
plt.grid(True)
plt.legend()
plt.show()
